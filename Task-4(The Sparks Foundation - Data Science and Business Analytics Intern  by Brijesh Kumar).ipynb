# %% [markdown]
# ## GRIP: The Spark Foundation

# %% [markdown]
# ###  Data science & Business Analytics Intern

# %% [markdown]
# ### Author: Brijesh Kumar

# %% [markdown]
# ### Task 4:Expoloratory data Analysis on terrorism

# %% [markdown]
# ### Importing the all required library for analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### loading the dataset (data string is latin 1 encoding instead of UTF-8 encoding)

# %%
df=pd.read_csv('C://Users//brije//Desktop//Global Terrorism - START data//globalterrorismdb_0718dist.csv',encoding="latin1")

# %%
df.head(5)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info(max_cols=150)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 135 columns):
#  #    Column              Non-Null Count   Dtype
# ---   ------              --------------   -----
#  0    eventid             181691 non-null  int64
#  1    iyear               181691 non-null  int64
#  2    imonth              181691 non-null  int64
#  3    iday                181691 non-null  int64
#  4    approxdate          9239 non-null    object
#  5    extended            181691 non-null  int64
#  6    resolution          2220 non-null    object
#  7    country             181691 non-null  int64
#  8    country_txt         181691 non-null  object
#  9    region              181691 non-null  int64
#  10   region_txt          181691 non-null  object
#  11   provstate           181270 non-null  object
#  12   city                181257 non-null  object
#  13   latitude            177135 non-null  float64
#  14   longitude           177134 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for i in df.columns:
    print(f"{i}",end=", ")
# Out:
# eventid, iyear, imonth, iday, approxdate, extended, resolution, country, country_txt, region, region_txt, provstate, city, latitude, longitude, specificity, vicinity, location, summary, crit1, crit2, crit3, doubtterr, alternative, alternative_txt, multiple, success, suicide, attacktype1, attacktype1_txt, attacktype2, attacktype2_txt, attacktype3, attacktype3_txt, targtype1, targtype1_txt, targsubtype1, targsubtype1_txt, corp1, target1, natlty1, natlty1_txt, targtype2, targtype2_txt, targsubtype2, targsubtype2_txt, corp2, target2, natlty2, natlty2_txt, targtype3, targtype3_txt, targsubtype3, targsubtype3_txt, corp3, target3, natlty3, natlty3_txt, gname, gsubname, gname2, gsubname2, gname3, gsubname3, motive, guncertain1, guncertain2, guncertain3, individual, nperps, nperpcap, claimed, claimmode, claimmode_txt, claim2, claimmode2, claimmode2_txt, claim3, claimmode3, claimmode3_txt, compclaim, weaptype1, weaptype1_txt, weapsubtype1, weapsubtype1_txt, weaptype2, weaptype2_txt, weapsubtyp
# ...

# %% [markdown]
# ### cleaning the data

# %%
df=df[["iyear","imonth","iday", "country_txt", "region_txt", "provstate","city", "latitude","longitude", "location", "summary","attacktype1_txt","targtype1_txt","gname","motive","weaptype1_txt","nkill", "nwound", "addnotes"]]

# %%
df.head(10)
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
# 5   1970       1     1       United States                North America
# 6   1970       1     2             Uruguay                South America
# 7   1970       1     2       United States                North America
# 8   1970       1     2       United States                North America
# 9   1970       1     3       United States                North America
#
#     provstate           city   latitude   longitude         location  \
# 0         NaN  Santo Domingo  18.456792  -69.951164              NaN
# ...

# %%
df.rename(columns={"iyear":"Year","imonth":"Month","day":"Day",
                   "country_txt":"Country", "region_txt":"Region", "provstate":"Province/State","city":"City",
                   "latitude":"Latitude","longitude":"Longitude","location":"Location","summary":"Summary",
                   "attacktype1_txt":"Attack Type","targtype1_txt":"Target Type","gname":"Group Name",
                   "notive": "Motive","weaptype1_txt":"Weapon Type",
                   "nkill":"Killed","nwound":"Wounded", "addnates": "Add Notes"},inplace=True)

# %%
df
# Out:
#         Year  Month  iday             Country                       Region  \
# 0       1970      7     2  Dominican Republic  Central America & Caribbean
# 1       1970      0     0              Mexico                North America
# 2       1970      1     0         Philippines               Southeast Asia
# 3       1970      1     0              Greece               Western Europe
# 4       1970      1     0               Japan                    East Asia
# ...      ...    ...   ...                 ...                          ...
# 181686  2017     12    31             Somalia           Sub-Saharan Africa
# 181687  2017     12    31               Syria   Middle East & North Africa
# 181688  2017     12    31         Philippines               Southeast Asia
# 181689  2017     12    31               India                   South Asia
# 181690  2017     12    31         Philippines               Southeast Asia
#
#          Province/State           City   Latitude   Longitude  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   iday            181691 non-null  int64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   Province/State  181270 non-null  object
#  6   City            181257 non-null  object
#  7   Latitude        177135 non-null  float64
#  8   Longitude       177134 non-null  float64
#  9   Location        55495 non-null   object
#  10  Summary         115562 non-null  object
#  11  Attack Type     181691 non-null  object
#  12  Target Type     181691 non-null  object
#  13  Group Name      181691 non-null  object
#  14  motive          50561 non-null   object
#  15  Weapon Type     181691 non-null  object
# ...

# %%
df.shape
# Out:
# (181691, 19)

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month                  0
# iday                   0
# Country                0
# Region                 0
# Province/State       421
# City                 434
# Latitude            4556
# Longitude           4557
# Location          126196
# Summary            66129
# Attack Type            0
# Target Type            0
# Group Name             0
# motive            131130
# Weapon Type            0
# Killed             10313
# Wounded            16311
# addnotes          153402
# dtype: int64

# %%
df['Killed']=df['Killed'].fillna(0)
df['Wounded']=df['Wounded'].fillna(0)
df['Casualty']=df['Killed']+df['Wounded']

# %%
df
# Out:
#         Year  Month  iday             Country                       Region  \
# 0       1970      7     2  Dominican Republic  Central America & Caribbean
# 1       1970      0     0              Mexico                North America
# 2       1970      1     0         Philippines               Southeast Asia
# 3       1970      1     0              Greece               Western Europe
# 4       1970      1     0               Japan                    East Asia
# ...      ...    ...   ...                 ...                          ...
# 181686  2017     12    31             Somalia           Sub-Saharan Africa
# 181687  2017     12    31               Syria   Middle East & North Africa
# 181688  2017     12    31         Philippines               Southeast Asia
# 181689  2017     12    31               India                   South Asia
# 181690  2017     12    31         Philippines               Southeast Asia
#
#          Province/State           City   Latitude   Longitude  \
# ...

# %%
df.describe()
# Out:
#                 Year          Month           iday       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded       Casualty
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883296       5.150156
# std    2.047790e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# ### Observation
#
# 1. The data consists of terrorist activities ranging from the year: 1970 to 2017
#
# 2. Maximum number of people killed in an event were: 1570
#
# 3. Maximum number of people wounded in an event were: 8191
#
# 4. Maximum number of total casurities in an event were: 9574

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# ### 1. Years wise attack

# %% [markdown]
# 1. No of attacks in each year

# %%
attacks=df['Year'].value_counts(dropna=True).sort_index().to_frame().reset_index().rename(columns={'index':'Years','Year':'attacks'}).set_index('Years')
attacks.head(10)
# Out:
#        attacks
# Years
# 1970       651
# 1971       471
# 1972       568
# 1973       473
# 1974       581
# 1975       740
# 1976       923
# 1977      1319
# 1978      1526
# 1979      2662

# %%
attacks.plot(kind='bar',figsize=(16,7),color='blue',fontsize=15)
plt.title('Timeline of attacks',fontsize=15)
plt.xlabel('Years',fontsize=15)
plt.ylabel('Number of attacks',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of attacks')

# %% [markdown]
#  - most number of attacks (16903)in 2014
#  - least number of attacks (471) in 1971

# %% [markdown]
# ### Total Casualty (killed and wounded) in each year

# %%
y=df[['Year','Casualty']].groupby('Year').sum()
y.head(10)
# Out:
#       Casualty
# Year
# 1970     386.0
# 1971     255.0
# 1972     975.0
# 1973     865.0
# 1974    1404.0
# 1975    1234.0
# 1976    1430.0
# 1977     974.0
# 1978    3059.0
# 1979    4606.0

# %%
y.plot(kind='bar',figsize=(14,7),color='orange',fontsize=10)
plt.title('Timeline of Casualty',fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.ylabel('Number of Casualty',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Casualty')

# %% [markdown]
# ### Killed in each Years

# %%
yk=df[['Year','Killed']].groupby('Year').sum()
yk.head(10)
# Out:
#       Killed
# Year
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0
# 1975   617.0
# 1976   674.0
# 1977   456.0
# 1978  1459.0
# 1979  2100.0

# %%
yk.plot(kind='bar',figsize=(14,7),color='red',fontsize=10)
plt.title('Killed year wise',fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.ylabel('Number of Killed',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Killed')

# %% [markdown]
# ### Wounded in each years

# %%
yw=df[['Year','Wounded']].groupby('Year').sum()
yw.head(10)
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0
# 1975    617.0
# 1976    756.0
# 1977    518.0
# 1978   1600.0
# 1979   2506.0

# %%
yw.plot(kind='bar',figsize=(14,7),color='purple',fontsize=10)
plt.title('Wounded year wise',fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.ylabel('Number of Wounded',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Wounded')

# %% [markdown]
# ### Region wise Attacks
#   1. Distribution of terrorist attacks over the years in regions

# %%
reg=pd.crosstab(df.Year,df.Region)
reg.head(10)
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
# 1975                        0                            9             0
# 1976                        0                           45             0
# 1977                        0                           24             0
# 1978                        2                          199             0
# 1979                        2                          609             0
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# ...

# %%
reg.plot(kind='area',figsize=(20,10),stacked=False,alpha=0.5)
plt.title('Regin wise attack',fontsize=15)
plt.xlabel('Regins',fontsize=15)
plt.ylabel('Number of attack',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of attack')

# %% [markdown]
# ### total terrorist attack in each region from 1970-2017

# %%
regt=reg.transpose()
regt['Total']=regt.sum(axis=1)
ra=regt['Total'].sort_values(ascending=False)
ra
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Total, dtype: int64

# %%
ra.plot(kind='bar',figsize=(20,10),fontsize=10)
plt.title('Total number of attack in each region 1970-2017',fontsize=15)
plt.xlabel('Regions',fontsize=15)
plt.ylabel('Number of attack',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of attack')

# %% [markdown]
# ### Total Casualities (killed+Wounded) in each regions

# %%
rc=df[['Region','Casualty']].groupby("Region").sum().sort_values('Casualty',ascending=False)
rc
# Out:
#                              Casualty
# Region
# Middle East & North Africa   351950.0
# South Asia                   242679.0
# Sub-Saharan Africa           131243.0
# South America                 45553.0
# Southeast Asia                41896.0
# Central America & Caribbean   37699.0
# North America                 26447.0
# Western Europe                25026.0
# Eastern Europe                19460.0
# East Asia                     10365.0
# Central Asia                   3009.0
# Australasia & Oceania           410.0

# %%
rc.plot(kind='bar',color='cornflowerblue',figsize=(20,8),fontsize=12)
plt.title('Region Wise Casualties between - 1970-2017',fontsize=15)
plt.xlabel('Regions',fontsize=15)
plt.ylabel('Number of Casualties',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Casualties')

# %% [markdown]
# ### Killed in each region

# %%
kr=df[['Region','Killed']].groupby("Region").sum().sort_values('Killed',ascending=False)
kr
# Out:
#                                Killed
# Region
# Middle East & North Africa   137642.0
# South Asia                   101319.0
# Sub-Saharan Africa            78386.0
# South America                 28849.0
# Central America & Caribbean   28708.0
# Southeast Asia                15637.0
# Eastern Europe                 7415.0
# Western Europe                 6694.0
# North America                  4916.0
# East Asia                      1152.0
# Central Asia                   1000.0
# Australasia & Oceania           150.0

# %%
kr.plot(kind='bar',color='orange',figsize=(20,8),fontsize=12)
plt.title('Region Wise Killed between - 1970-2017',fontsize=15)
plt.xlabel('Regions',fontsize=15)
plt.ylabel('Number of Killed',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Killed')

# %%
wr=df[['Region','Wounded']].groupby("Region").sum().sort_values('Wounded',ascending=False)
wr
# Out:
#                               Wounded
# Region
# Middle East & North Africa   214308.0
# South Asia                   141360.0
# Sub-Saharan Africa            52857.0
# Southeast Asia                26259.0
# North America                 21531.0
# Western Europe                18332.0
# South America                 16704.0
# Eastern Europe                12045.0
# East Asia                      9213.0
# Central America & Caribbean    8991.0
# Central Asia                   2009.0
# Australasia & Oceania           260.0

# %%
wr.plot(kind='bar',color='green',figsize=(20,8),fontsize=12)
plt.title('Region Wise Wounded between - 1970-2017',fontsize=15)
plt.xlabel('Regions',fontsize=15)
plt.ylabel('Number of Wounded',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Wounded')

# %% [markdown]
# ### contry wise attack top-10

# %% [markdown]
# Number of attack in each country

# %%
ct=df['Country'].value_counts().head(10)
ct
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
ct.plot(kind='bar',color='violet',figsize=(20,8),fontsize=12)
plt.title('Country wise attacks - 1970-2017',fontsize=15)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Number of attacks',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of attacks')

# %% [markdown]
# ### Total casualties (killed + wounded) in each country

# %%
tc=df[['Country','Casualty']].groupby('Country').sum().sort_values(by='Casualty',ascending=False)
tc.head(10)
# Out:
#                Casualty
# Country
# Iraq           213279.0
# Afghanistan     83661.0
# Pakistan        65860.0
# India           48321.0
# Nigeria         32921.0
# Sri Lanka       31091.0
# Syria           29338.0
# Colombia        25026.0
# United States   24473.0
# Philippines     22926.0

# %%
tc[:10].plot(kind='bar',color='red',figsize=(20,8),fontsize=12)
plt.title('Country wise Casualties - 1970-2017',fontsize=15)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Number of Casualties',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Casualties')

# %%
kc=df[['Country','Killed']].groupby('Country').sum().sort_values(by='Killed',ascending=False)
kc
# Out:
#                       Killed
# Country
# Iraq                 78589.0
# Afghanistan          39384.0
# Pakistan             23822.0
# Nigeria              22682.0
# India                19341.0
# ...                      ...
# St. Kitts and Nevis      0.0
# Martinique               0.0
# Brunei                   0.0
# Iceland                  0.0
# South Yemen              0.0
#
# [205 rows x 1 columns]

# %%
kc[:10].plot(kind='bar',color='Orange',figsize=(20,8),fontsize=12)
plt.title('Country wise Killed - 1970-2017',fontsize=15)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Number of Killed',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Killed')

# %% [markdown]
# ### City wise attacks

# %%
city=df['City'].value_counts()[1:11]
city
# Out:
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Name: City, dtype: int64

# %%
city.plot(kind='bar',color='Purple',figsize=(20,8),fontsize=12)
plt.title('City wise attacks- 1970-2017',fontsize=15)
plt.xlabel('City',fontsize=15)
plt.ylabel('Number of Attacks',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Attacks')

# %% [markdown]
# ### City wise Casualties

# %%
cc=df[['City','Casualty']].groupby('City').sum().sort_values(by='Casualty',ascending=False).drop('Unknown')
cc
# Out:
#                Casualty
# City
# Baghdad         77876.0
# New York City   19619.0
# Mosul           12927.0
# Karachi          9376.0
# Mogadishu        8868.0
# ...                 ...
# Divandarreh         0.0
# Diva                0.0
# Padaiya             0.0
# Padalangala         0.0
# zinarag             0.0
#
# [36673 rows x 1 columns]

# %%
cc[:11].plot(kind='bar',color='Purple',figsize=(20,8),fontsize=12)
plt.title('City wise Casulties - 1970-2017',fontsize=15)
plt.xlabel('City',fontsize=15)
plt.ylabel('Number of Casualties',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Casualties')

# %% [markdown]
# ### Killed in each City

# %%
kc=df[['City','Killed']].groupby('City').sum().sort_values(by="Killed",ascending=False).drop('Unknown')
kc
# Out:
#                    Killed
# City
# Baghdad           21151.0
# Mosul              7140.0
# Mogadishu          3913.0
# Karachi            3688.0
# New York City      2838.0
# ...                   ...
# Mohib Banda           0.0
# Mohill                0.0
# Chapai Nawabganj      0.0
# Chapaguri             0.0
# zinarag               0.0
#
# [36673 rows x 1 columns]

# %%
kc[:11].plot(kind='bar',color='red',figsize=(20,8),fontsize=12)
plt.title('City wise Killed - 1970-2017',fontsize=15)
plt.xlabel('City',fontsize=15)
plt.ylabel('Number of Killed',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Killed')

# %%
wc=df[['City','Wounded']].groupby('City').sum().sort_values(by="Wounded",ascending=False).drop('Unknown')
wc
# Out:
#                Wounded
# City
# Baghdad        56725.0
# New York City  16781.0
# Kabul           5973.0
# Mosul           5787.0
# Karachi         5688.0
# ...                ...
# Kalaong            0.0
# Kalantra           0.0
# Kalangar           0.0
# Kalanch            0.0
# zinarag            0.0
#
# [36673 rows x 1 columns]

# %%
wc[:11].plot(kind='bar',color='red',figsize=(20,8),fontsize=12)
plt.title('City wise Wounded - 1970-2017',fontsize=15)
plt.xlabel('City',fontsize=15)
plt.ylabel('Number of Wounded',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Wounded')

# %%
fig=plt.figure(figsize=(15,10))
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

kc[:11].plot(kind='bar',color='red',figsize=(20,8),fontsize=12,ax=ax0)
ax0.set_title('City wise Killed - 1970-2017',fontsize=15)
ax0.set_xlabel('City',fontsize=15)
ax0.set_ylabel('Number of Killed',fontsize=15)

wc[:11].plot(kind='bar',color='blue',figsize=(20,8),fontsize=12,ax=ax1)
ax1.set_title('City wise Wounded - 1970-2017',fontsize=15)
ax1.set_xlabel('City',fontsize=15)
ax1.set_ylabel('Number of Wounded',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Wounded')

# %% [markdown]
# ### Terrorist Group wise Attacks

# %% [markdown]
# Number of Attacks by each group

# %%
grp=df['Group Name'].value_counts().drop('Unknown')
grp
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
#                                                     ...
# Ansar Sarallah                                         1
# Sword of Islam                                         1
# Support of Ocalan-The Hawks of Thrace                  1
# Arab Revolutionary Front                               1
# MANO-D                                                 1
# Name: Group Name, Length: 3536, dtype: int64

# %%
grp[:11].plot(kind='bar',color='orange',figsize=(20,8),fontsize=12)
plt.title('Group wise Attacks - 1970-2017',fontsize=15)
plt.xlabel('Group name',fontsize=15)
plt.ylabel('Number of Attacks',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Attacks')

# %% [markdown]
# ### Total casualty by each group

# %%
gc=df[['Group Name','Casualty']].groupby('Group Name').sum().sort_values(by="Casualty",ascending=False).drop('Unknown')
gc
# Out:
#                                                     Casualty
# Group Name
# Islamic State of Iraq and the Levant (ISIL)          69595.0
# Taliban                                              57342.0
# Boko Haram                                           29801.0
# Al-Qaida                                             28372.0
# Liberation Tigers of Tamil Eelam (LTTE)              22020.0
# ...                                                      ...
# Popular Revolutionary Action                             0.0
# Popular Resistance Sabotage Group                        0.0
# Force Etudiante Critique                                 0.0
# Forces for the Unification of the Central Afric...       0.0
# leftist guerrillas-Bolivarian militia                    0.0
#
# [3536 rows x 1 columns]

# %%
gc[:11].plot(kind='bar',color='blue',figsize=(20,8),fontsize=12)
plt.title('Group wise Casualties - 1970-2017',fontsize=15)
plt.xlabel('Group name',fontsize=15)
plt.ylabel('Number of Casualty',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Casualty')

# %%
gk=df[['Group Name','Killed']].groupby('Group Name').sum().sort_values(by="Killed",ascending=False).drop('Unknown')
gk
# Out:
#                                               Killed
# Group Name
# Islamic State of Iraq and the Levant (ISIL)  38923.0
# Taliban                                      29410.0
# Boko Haram                                   20328.0
# Shining Path (SL)                            11601.0
# Liberation Tigers of Tamil Eelam (LTTE)      10989.0
# ...                                              ...
# New Revolutionary Alternative (NRA)              0.0
# Council for the Destruction of Order             0.0
# Counterrevolutionary Solidarity (SC)             0.0
# New Partisans Movement                           0.0
# leftist guerrillas-Bolivarian militia            0.0
#
# [3536 rows x 1 columns]

# %%
gk[:11].plot(kind='bar',color='red',figsize=(20,8),fontsize=12)
plt.title('Group wise Killed - 1970-2017',fontsize=15)
plt.xlabel('Group name',fontsize=15)
plt.ylabel('Number of Killed',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Killed')

# %% [markdown]
# ### Attack type wise attacks

# %% [markdown]
# Number of attacks by each attack type

# %%
at=df['Attack Type'].value_counts().drop("Unknown")
at
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack Type, dtype: int64

# %%
at.plot(kind='bar',color='pink',figsize=(20,8),fontsize=12)
plt.title('Number of attacks by each attack type - 1970-2017',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.ylabel('Number of Attacks',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Attacks')

# %% [markdown]
# ### Total Casualtie(Wounded+Kiled) in each Attacks

# %%
ac=df[['Attack Type','Casualty']].groupby('Attack Type').sum().sort_values(by="Casualty",ascending=False)
ac
# Out:
#                                      Casualty
# Attack Type
# Bombing/Explosion                    530007.0
# Armed Assault                        237663.0
# Unknown                               47106.0
# Assassination                         38807.0
# Hostage Taking (Kidnapping)           30677.0
# Hijacking                             20719.0
# Unarmed Assault                       14907.0
# Hostage Taking (Barricade Incident)    8444.0
# Facility/Infrastructure Attack         7407.0

# %%
ac.plot(kind='bar',color='Orange',figsize=(20,8),fontsize=12)
plt.title('Total Casualtie(Wounded+Kiled) in each Attacks - 1970-2017',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.ylabel('Number of Casualty',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Casualty')

# %% [markdown]
# ### killed in each attack type

# %%
ka=df[['Attack Type','Killed']].groupby('Attack Type').sum().sort_values(by='Killed',ascending=False).drop("Unknown")
ka
# Out:
#                                        Killed
# Attack Type
# Armed Assault                        160297.0
# Bombing/Explosion                    157321.0
# Assassination                         24920.0
# Hostage Taking (Kidnapping)           24231.0
# Hostage Taking (Barricade Incident)    4478.0
# Hijacking                              3718.0
# Facility/Infrastructure Attack         3642.0
# Unarmed Assault                         880.0

# %% [markdown]
# #### Wounded by each attack type

# %%
aw=df[['Attack Type','Wounded']].groupby('Attack Type').sum().sort_values(by='Wounded',ascending=False).drop("Unknown")
aw
# Out:
#                                       Wounded
# Attack Type
# Bombing/Explosion                    372686.0
# Armed Assault                         77366.0
# Hijacking                             17001.0
# Unarmed Assault                       14027.0
# Assassination                         13887.0
# Hostage Taking (Kidnapping)            6446.0
# Hostage Taking (Barricade Incident)    3966.0
# Facility/Infrastructure Attack         3765.0

# %%
fig=plt.figure(figsize=(15,10))
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

ka[:11].plot(kind='bar',color='red',figsize=(20,8),fontsize=12,ax=ax0)
ax0.set_title('killed in each attack type - 1970-2017',fontsize=15)
ax0.set_xlabel('Attack Type',fontsize=15)
ax0.set_ylabel('Number of Killed',fontsize=15)

aw[:11].plot(kind='bar',color='blue',figsize=(20,8),fontsize=12,ax=ax1)
ax1.set_title('Wounded by each attack type - 1970-2017',fontsize=15)
ax1.set_xlabel('Attack Type',fontsize=15)
ax1.set_ylabel('Number of Wounded',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Wounded')

# %% [markdown]
# ### Target type wise attacks

# %% [markdown]
# Number of attacks over each target type

# %%
ta=df['Target Type'].value_counts()
ta
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target Type, dtype: int64

# %%
ta.plot(kind='bar',color='cornflowerblue',figsize=(20,8),fontsize=12)
plt.title('Type of Targets - 1970-2017',fontsize=15)
plt.xlabel('Target type',fontsize=15)
plt.ylabel('Number of Attacks',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Attacks')

# %%
tc=df[['Target Type','Casualty']].groupby('Target Type').sum().sort_values(by='Casualty',ascending=False)
tc
# Out:
#                                 Casualty
# Target Type
# Private Citizens & Property     319176.0
# Military                        177085.0
# Police                          118407.0
# Business                         78018.0
# Government (General)             67255.0
# Transportation                   54595.0
# Religious Figures/Institutions   37890.0
# Terrorists/Non-State Militia     17311.0
# Educational Institution          13972.0
# Government (Diplomatic)          13398.0
# Violent Political Party           8920.0
# Unknown                           7888.0
# Airports & Aircraft               7245.0
# Journalists & Media               3297.0
# Utilities                         3227.0
# Maritime                          2099.0
# Tourists                          2048.0
# NGO                               1950.0
# Telecommunication                  679.0
# Other                              674.0
# Food or Water Supply               547.0
# ...

# %%
tc.plot(kind='bar',color='red',figsize=(20,8),fontsize=12)
plt.title('Total Casulties in Type of Targets - 1970-2017',fontsize=15)
plt.xlabel('Target type',fontsize=15)
plt.ylabel('Number of Casulties',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Casulties')

# %%
tk=df[['Target Type','Killed']].groupby('Target Type').sum().sort_values(by='Killed',ascending=False)
tk
# Out:
#                                   Killed
# Target Type
# Private Citizens & Property     140504.0
# Military                        106047.0
# Police                           53704.0
# Government (General)             26071.0
# Business                         23487.0
# Transportation                   13916.0
# Religious Figures/Institutions   13413.0
# Terrorists/Non-State Militia      9088.0
# Unknown                           4329.0
# Airports & Aircraft               3767.0
# Educational Institution           3745.0
# Violent Political Party           3617.0
# Government (Diplomatic)           3039.0
# Utilities                         1874.0
# Journalists & Media               1501.0
# Maritime                          1191.0
# NGO                               1057.0
# Tourists                           758.0
# Food or Water Supply               313.0
# Other                              255.0
# Telecommunication                  182.0
# ...

# %%
tk.plot(kind='bar',color='orange',figsize=(20,8),fontsize=12)
plt.title('Total Killed in Type of Targets - 1970-2017',fontsize=15)
plt.xlabel('Target type',fontsize=15)
plt.ylabel('Number of Killed',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Killed')

# %%
tw=df[['Target Type','Wounded']].groupby('Target Type').sum().sort_values(by='Wounded',ascending=False)
tw
# Out:
#                                  Wounded
# Target Type
# Private Citizens & Property     178672.0
# Military                         71038.0
# Police                           64703.0
# Business                         54531.0
# Government (General)             41184.0
# Transportation                   40679.0
# Religious Figures/Institutions   24477.0
# Government (Diplomatic)          10359.0
# Educational Institution          10227.0
# Terrorists/Non-State Militia      8223.0
# Violent Political Party           5303.0
# Unknown                           3559.0
# Airports & Aircraft               3478.0
# Journalists & Media               1796.0
# Utilities                         1353.0
# Tourists                          1290.0
# Maritime                           908.0
# NGO                                893.0
# Telecommunication                  497.0
# Other                              419.0
# Food or Water Supply               234.0
# ...

# %%
tw.plot(kind='bar',color='Yellow',figsize=(20,8),fontsize=12)
plt.title('Total Wounded in Type of Targets - 1970-2017',fontsize=15)
plt.xlabel('Target type',fontsize=15)
plt.ylabel('Number of Wounded',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Wounded')

# %% [markdown]
# ### Group + Country wise - Top10

# %% [markdown]
# Sorting by number of attacks

# %%
gca=df[['Group Name','Country']].value_counts().drop("Unknown")
gca.head(10)
# Out:
# Group Name                                        Country
# Taliban                                           Afghanistan       7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq              4797
# Shining Path (SL)                                 Peru              4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       3330
# Al-Shabaab                                        Somalia           2867
# New People's Army (NPA)                           Philippines       2770
# Irish Republican Army (IRA)                       United Kingdom    2575
# Revolutionary Armed Forces of Colombia (FARC)     Colombia          2468
# Kurdistan Workers' Party (PKK)                    Turkey            2109
# Boko Haram                                        Nigeria           2087
# dtype: int64

# %%
gca[:11].plot(kind='bar',color='blue',figsize=(20,8),fontsize=12)
plt.title('Country with most attacks by a particular group - 1970-2017',fontsize=15)
plt.xlabel('Group Names',fontsize=15)
plt.ylabel('Number of Attacks',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Attacks')

# %% [markdown]
# ### Sorting by Number of Casualties

# %%
gcc=df[['Group Name','Country','Casualty']].groupby(['Group Name','Country'],axis=0).sum().sort_values(by='Casualty',ascending=False).drop('Unknown')
gcc
# Out:
#                                                            Casualty
# Group Name                                  Country
# Taliban                                     Afghanistan     57140.0
# Islamic State of Iraq and the Levant (ISIL) Iraq            54755.0
# Boko Haram                                  Nigeria         24588.0
# Liberation Tigers of Tamil Eelam (LTTE)     Sri Lanka       21919.0
# Al-Qaida                                    United States   19494.0
# ...                                                             ...
# People's Information Group                  Nicaragua           0.0
# Drug-Related Terrorists                     Haiti               0.0
# People's Liberation Army (United States)    United States       0.0
# Down with Lubbers                           Netherlands         0.0
# leftist guerrillas-Bolivarian militia       Colombia            0.0
#
# [5171 rows x 1 columns]

# %%
gcc[:11].plot(kind='bar',color='blue',figsize=(20,8),fontsize=12)
plt.title('Country with most Casualties by a particular group - 1970-2017',fontsize=15)
plt.xlabel('Group Names,Country',fontsize=15)
plt.ylabel('Number of Casualties',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Casualties')

# %%
gck=df[['Group Name','Country','Killed']].groupby(['Group Name','Country'],axis=0).sum().sort_values(by='Killed',ascending=False).drop('Unknown')
gck
# Out:
#                                                                  Killed
# Group Name                                  Country
# Islamic State of Iraq and the Levant (ISIL) Iraq                31058.0
# Taliban                                     Afghanistan         29269.0
# Boko Haram                                  Nigeria             16917.0
# Shining Path (SL)                           Peru                11595.0
# Liberation Tigers of Tamil Eelam (LTTE)     Sri Lanka           10928.0
# ...                                                                 ...
# Civil War Veterans                          Liberia                 0.0
# Mustafa Aktas Fighting Unit                 West Germany (FRG)      0.0
# Mustafa al-Hujairi Group                    Lebanon                 0.0
# Mutahida Majlis-e-Amal                      Pakistan                0.0
# leftist guerrillas-Bolivarian militia       Colombia                0.0
#
# [5171 rows x 1 columns]

# %%
gck[:11].plot(kind='bar',color='orange',figsize=(20,8),fontsize=12)
plt.title('Country with most Killed by a particular group - 1970-2017',fontsize=15)
plt.xlabel('Group Names,Country',fontsize=15)
plt.ylabel('Number of Killed',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Killed')

# %% [markdown]
# Sorting the Number of people Wounded

# %%
gcw=df[['Group Name','Country','Wounded']].groupby(['Group Name','Country'],axis=0).sum().sort_values(by='Wounded',ascending=False).drop('Unknown')
gcw
# Out:
#                                                              Wounded
# Group Name                                  Country
# Taliban                                     Afghanistan      27871.0
# Islamic State of Iraq and the Levant (ISIL) Iraq             23697.0
# Al-Qaida                                    United States    16493.0
# Liberation Tigers of Tamil Eelam (LTTE)     Sri Lanka        10991.0
# Al-Qaida in Iraq                            Iraq             10075.0
# ...                                                              ...
# Irrintzi                                    France               0.0
# Isatabu Freedom Movement (IFM)              Solomon Islands      0.0
# Islam Liberation Front                      Algeria              0.0
# Islami Jamiat-e-Talaba (IJT)                Pakistan             0.0
# leftist guerrillas-Bolivarian militia       Colombia             0.0
#
# [5171 rows x 1 columns]

# %%
gcw[:11].plot(kind='bar',color='violet',figsize=(20,8),fontsize=12)
plt.title('Country with most wounded by a particular group - 1970-2017',fontsize=15)
plt.xlabel('Group Names,Country',fontsize=15)
plt.ylabel('Number of Wounded',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Wounded')

# %% [markdown]
# ### Humanity affacted (world wide ) by terrorist attack from 1970 to 2017

# %% [markdown]
# Total Casualtie (killed + Wounded) by terrist attacks

# %%
casualties=df.loc[:,['Casualty']].sum()
print("Total Number of Casualties due terrorist attcks from 1970 to 2017 across the world",casualties)
# Out:
# Total Number of Casualties due terrorist attcks from 1970 to 2017 across the world Casualty    935737.0
# dtype: float64

# %% [markdown]
# Total killed  by terrist attacks

# %%
kill=df.loc[:,['Killed']].sum()
print("Total Number of Killed due terrorist attcks from 1970 to 2017 across the world",kill)
# Out:
# Total Number of Killed due terrorist attcks from 1970 to 2017 across the world Killed    411868.0
# dtype: float64

# %% [markdown]
# wounded due to terrorist attacks

# %%
wound=df.loc[:,['Wounded']].sum()
print("Total Number of wounded due terrorist attcks from 1970 to 2017 across the world",wound)
# Out:
# Total Number of wounded due terrorist attcks from 1970 to 2017 across the world Wounded    523869.0
# dtype: float64

# %% [markdown]
# ### Obervation

# %% [markdown]
# 1. Year wise Attacks :
#
# (i) Attacks
#
# (a) Most number of attacks: 16903 in 2014
# (b) Least number of attacks: 471 in 1971
#
# (ii) Casualties
#
# (a) Most number of casualties: 85618 in 2014
# (b) Least number of casualties: 255 in 1971
#
# (iii) Killed
# (a) Most number of people killed: 44490 in 2014
# (b) Least number of people killed: 173 in 1971
#
# (iv) Wounded
# (a) Most number of people wounded: 44043 in 2015
# (b) Least number of people wounded: 82 in 1971
#
# 2. Region wise Attacks:
#
# (1) Attacks
#
# (a) Most number of attacks: 50474 in "Middle East & North Africa"
#
# (b) Least number of attacks: 282 in "Australasia & Oceania"
#
# (ii) Casualties
#
# (a) Most number of casualties: 351950 in "Middle East & North Africa"
# (b) Least number of casualties: 410 in Australasia & Oceania
#
# (ii) Casualties
#
# (a) Most number of casualties: 351950 in "Middle East & North Africa"
# (b) Least number of casualties: 410 in Australasia & Oceania
#
# (iii) Killed
# (a) Most number of people killed: 137642 in "Middle East & North Africa"
# (b) Least number of people killed: 150 in "Australasia & Oceania"
#
#
# (iv) Wounded
#
# (a) Most number of people wounded: 214308 in "Middle East & North Africa"
# (b) Least number of people wounded: 260 in "Australasia & Oceania"
#
# 3. Country wise Attacks [Top-10]:
#
# (1) Attacks
#
# (a) Most number of attacks: 24636 in "Iraq"
#
# (b) Least number of attacks: 4292 in "Turkey"
#
# (ii) Casualties
# (a) Most number of casualties: 213279 in "Iraq"
# (b) Least number of casualties: 22926 in "Philippines"
#
# (i) Killed
# (a) Most number of people killed: 78589 in "Iraq"
# (b) Least number of people killed: 12053 in "El Salvador"
#
# (iv) Wounded
# (a) Most number of people wounded: 134690 in "Iraq"
# (b) Least number of people wounded: 10328 in "Colombia"
#
# 4. City wise Attacks [Top 10]:
#
# (1) Attacks
# (a) Most number of attacks: 7589 in "Baghdad"
# (b) Least number of attacks: 1019 in "Athens"
#
# (ii) Casualties
# (a) Most number of casualties: 77876 in "Baghdad"
# (b) Least number of casualties: 5748 in "Aleppo"
#
# (2) Killed
# (a) Most number of people wounded: 56725 in "Baghdad"
# (b) Least number of people wounded: 4955 in "Mogadishu"
#
# 5. Terrorist Group wise Attacks [Top 10]:
#
# (1) Attacks
# (a) Most number of attacks: 7478 by "Taliban"
# (b) Least number of attacks: 2418 by "Boko Haram"
#
# (ii) Casualties
# (a) Most number of casualties: 69595 by "Islamic State of Iraq and the Levant (ISIL)"
# (b) Least number of casualties: 12130 by "Farabundo Marti National Liberation Front (FMLN)"
#
# (i) Killed
# (a) Most number of people killed: 38923 by "Islamic State of Iraq and the Levant (ISIL)"
# (b) Least number of people killed: 5661 by "Revolutionary Armed Forces of Colombia (FARC)"
#
# (iv) Wounded
# (a) Most number of people wounded: 30672 by "Islamic State of Iraq and the Levant (ISIL)"
# (b) Least number of people wounded: 4908 by "Kurdistan Workers' Party (PKK)"
#
# 6. Attack type wise attacks:
#
# (1) Attacks
# (a) Most number of attacks: 88255 by "Bombing/Explosion"
# (b) Least number of attacks: 659 by "Hijacking"
#
# (ii) Casualties
# (a) Most number of casualties: 530007 by "Bombing/Explosion"
# (b) Least number of casualties: 7407 by "Facility/Infrastructure Attack"
#
# (iii) Killed
# (a) Most number of people killed: 160297 by "Armed Assault"
# (b) Least number of people killed: 880 by "Unarmed Assault"
#
#
# (iv) Wounded
# (a) Most number of people wounded: 372686 by "Bombing/Explosion"
# (b) Least number of people wounded: 3765 by "Facility/Infrastructure Attack"
#
# 7. Target Type wise Attacks:
#
# (1) Attacks
# (a) Most number of attacks: 43511 over "Private Citizens & Property"
# (b) Least number of attacks: 263 over "Abortion Related"
#
# (ii) Casualties
# (a) Most number of casualties: 319176 over "Private Citizens & Property"
# (b) Least number of casualties: 56 over "Abortion Related"
#
# (ii) Killed
# (a) Most number of people killed: 140504 over "Private Citizens & Property"
# (b) Least number of people killed: 10 over "Abortion Related"
#
# (iv) Wounded
# (a) Most number of people wounded: 178672 over "Private Citizens & Property"
# (b) Least number of people wounded: 46 over "Abortion Related"
#
# 8. Group and Country wise Attacks [Top 10]:
#
# (i) Attacks
# (a) Most number of attacks: 7423 by "Taliban" in "Afghanistan"
# (b) Least number of attacks: 2087 by "Boko Haram" in "Nigeria"
#
# (ii) Casualties
# (a) Most number of casualties: 57140 by "Taliban" in "Afghanistan"
# (b) Least number of casualties: 12068 by "Farabundo Marti National Liberation Front (FMLN)" in "El Salvador".
#
# (iii) Killed
# (a) Most number of people killed: 31058 by "Islamic State of Iraq and the Levant (ISIL)" in "Iraq"
# (b) Least number of people killed: 6014 by "Tehrik-i-Taliban Pakistan (TTP)" in "Pakistan"
#
# (iv) Wounded
# (a) Most number of people wounded: 27871 by "Taliban" in "Afghanistan"
# (b) Least number of people wounded: 4795 by "Kurdistan Workers' Party (PKK) in Turkey"
#
#
# 9. Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017:
#
# (i) Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world: 935737
#
# (ii) Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world: 411868
#
# (iii) Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world: 523869

# %% [markdown]
#  ### Thank You!
